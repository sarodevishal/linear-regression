# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
this=Series([2,3,4,5])
this
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
this.values
# Out:
# array([2, 3, 4, 5], dtype=int64)

# %%
this.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
citypopulation_2016=Series([2345,2345,56767,34456,5678],
index=["NYC",'LA',"chicago","Houston","phonix"])
citypopulation_2016
# Out:
# NYC         2345
# LA          2345
# chicago    56767
# Houston    34456
# phonix      5678
# dtype: int64

# %%
citypopulation_2016[citypopulation_2016>20000]
# Out:
# chicago    56767
# Houston    34456
# dtype: int64

# %%
citypopulation_2016[citypopulation_2016<20000]
# Out:
# NYC       2345
# LA        2345
# phonix    5678
# dtype: int64

# %%
#whether chicago is in thew series
"LA" in citypopulation_2016
# Out:
# True

# %%
"India" not in citypopulation_2016
# Out:
# True

# %%
cities=["NYC",'LA',"chicago","Houston","phonix"]
a=Series(citypopulation_2016,index=cities)
print(a)
# Out:
# NYC         2345
# LA          2345
# chicago    56767
# Houston    34456
# phonix      5678
# dtype: int64

# %%
a.isnull()
# Out:
# NYC        False
# LA         False
# chicago    False
# Houston    False
# phonix     False
# dtype: bool

# %%
#Adding the two series
a1=a+citypopulation_2016
a1
# Out:
# NYC          4690
# LA           4690
# chicago    113534
# Houston     68912
# phonix      11356
# dtype: int64

# %%
#name the seies
a1.index.name=cities
a1
# Out:
# [NYC, LA, chicago, Houston, phonix]
# NYC          4690
# LA           4690
# chicago    113534
# Houston     68912
# phonix      11356
# dtype: int64

# %%
df=pd.read_csv("input.csv")
df
# Out:
#      name  age  marks   colour
# 0  vishal   23     113     red
# 1     abc   33     119    blue
# 2     acd   43     125  yellow
# 3     ada   53     131    blue
# 4    afaf   63     137    blue
# 5     gds   73     143  yellow
# 6  sgdsgs   83     149     red
# 7     sdg   93     155     red
# 8     sgs  103     161  yellow
# 9     seg  113     167    blue

# %%
import pandas as pd
a=pd.read_csv("mls-salaries-2016.csv")
a
# Out:
#     club     last_name first_name position  base_salary  \
# 0    ATL        Burgos     Efrain        M     62508.00
# 1    ATL  Oblitey Otoo    Jeffrey        M     51504.00
# 2    ATL      Tambakis  Alexander       GK     63000.00
# 3    CHI         Accam      David      F-M    700000.00
# 4    CHI       Alvarez     Arturo        F    115000.00
# 5    CHI      Calistri       Joey        M     51500.00
# 6    CHI      Campbell   Jonathan        D     70000.00
# 7    CHI         Cocis     Razvan        M    160000.00
# 8    CHI        Conner       Drew        M     62500.00
# 9    CHI         Doody    Patrick        D     53471.00
# 10   CHI     Fernandez     Collin        M     75000.00
# 11   CHI        Gehrig       Eric        D    106875.00
# 12   CHI      Goossens       John        M    200000.00
# 13   CHI    Harrington    Michael        D    125000.00
# 14   CHI   Igboananike    Kennedy        F    800000.00
# 15   CHI       Johnson       Sean       GK    250000.00
# ...

# %%
a.head()
# Out:
#   club     last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL        Burgos     Efrain        M      62508.0                  62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0                  51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0                  63000.0
# 3  CHI         Accam      David      F-M     700000.0                 770937.5
# 4  CHI       Alvarez     Arturo        F     115000.0                 118264.0

# %%
a.tail()
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 550  NaN  Martinez   Cristian        M     62508.00                 67008.00
# 551  NaN     Moore       Luke        F    115000.00                137500.00
# 552  NaN    Nyassi      Sanna        M    135000.00                141250.00
# 553  NaN    Ovalle     Adolfo        M     63000.00                 73500.00
# 554  NaN    Tshuma    Schillo        F     81999.96                119999.96

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 6 columns):
# club                       549 non-null object
# last_name                  555 non-null object
# first_name                 553 non-null object
# position                   555 non-null object
# base_salary                555 non-null float64
# guaranteed_compensation    555 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 26.1+ KB

# %%
a["last_name"].head()
# Out:
# 0          Burgos
# 1    Oblitey Otoo
# 2        Tambakis
# 3           Accam
# 4         Alvarez
# Name: last_name, dtype: object

# %%
DataFrame(a,columns=["last_name","first_name","base_salary"])
# Out:
#         last_name first_name  base_salary
# 0          Burgos     Efrain     62508.00
# 1    Oblitey Otoo    Jeffrey     51504.00
# 2        Tambakis  Alexander     63000.00
# 3           Accam      David    700000.00
# 4         Alvarez     Arturo    115000.00
# 5        Calistri       Joey     51500.00
# 6        Campbell   Jonathan     70000.00
# 7           Cocis     Razvan    160000.00
# 8          Conner       Drew     62500.00
# 9           Doody    Patrick     53471.00
# 10      Fernandez     Collin     75000.00
# 11         Gehrig       Eric    106875.00
# 12       Goossens       John    200000.00
# 13     Harrington    Michael    125000.00
# 14    Igboananike    Kennedy    800000.00
# 15        Johnson       Sean    250000.00
# 16         Junior   Gilberto   1145000.00
# 17      Kappelhof      Johan    480000.00
# 18       LaBrocca       Nick    110000.00
# 19        Lampson       Matt     71250.00
# 20         McLain    Patrick     72500.00
# ...

# %%
a.head()
# Out:
#   club     last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL        Burgos     Efrain        M      62508.0                  62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0                  51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0                  63000.0
# 3  CHI         Accam      David      F-M     700000.0                 770937.5
# 4  CHI       Alvarez     Arturo        F     115000.0                 118264.0

# %%
a.iloc[2]#columns name
# Out:
# club                             ATL
# last_name                   Tambakis
# first_name                 Alexander
# position                          GK
# base_salary                    63000
# guaranteed_compensation        63000
# Name: 2, dtype: object

# %%
a["base_salary"]=a["base_salary"]*2
a.head()
# Out:
#   club     last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL        Burgos     Efrain        M     125016.0                  62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M     103008.0                  51504.0
# 2  ATL      Tambakis  Alexander       GK     126000.0                  63000.0
# 3  CHI         Accam      David      F-M    1400000.0                 770937.5
# 4  CHI       Alvarez     Arturo        F     230000.0                 118264.0

# %%
a["tax"]="100"#new column is created
a.head()
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M     125016.0
# 1  ATL  Oblitey Otoo    Jeffrey        M     103008.0
# 2  ATL      Tambakis  Alexander       GK     126000.0
# 3  CHI         Accam      David      F-M    1400000.0
# 4  CHI       Alvarez     Arturo        F     230000.0
#
#    guaranteed_compensation  tax
# 0                  62508.0  100
# 1                  51504.0  100
# 2                  63000.0  100
# 3                 770937.5  100
# 4                 118264.0  100

# %%
a.head()#we use del function
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M     125016.0
# 1  ATL  Oblitey Otoo    Jeffrey        M     103008.0
# 2  ATL      Tambakis  Alexander       GK     126000.0
# 3  CHI         Accam      David      F-M    1400000.0
# 4  CHI       Alvarez     Arturo        F     230000.0
#
#    guaranteed_compensation  tax
# 0                  62508.0  100
# 1                  51504.0  100
# 2                  63000.0  100
# 3                 770937.5  100
# 4                 118264.0  100

# %%
#dataframe from dic
fruits={"fruit":["orange","apple","grapes","Mangoes"],"price":[20,30,40,50]}
a=DataFrame(fruits)
a
# Out:
#      fruit  price
# 0   orange     20
# 1    apple     30
# 2   grapes     40
# 3  Mangoes     50

# %%
#reindexing
a=Series([2,3,5,7],index=["red","blue","green","black"])
a
# Out:
# red      2
# blue     3
# green    5
# black    7
# dtype: int64

# %%
a.reindex(["red","blue","orange","black"])
# Out:
# red       2.0
# blue      3.0
# orange    NaN
# black     7.0
# dtype: float64

# %%
a=DataFrame(np.random.random_integers(25,size=(25)).reshape((5,5)),index=["a","b","c","d","e"],columns=["col1","col2","col3","cl4","col5"])
a
# Out:
# C:\Users\vishal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 25 + 1) instead
#   """Entry point for launching an IPython kernel.
#    col1  col2  col3  cl4  col5
# a    24    14    11   18     7
# b     3    23    10   20     7
# c     8    11     3   21    13
# d    15     4     1   12     7
# e     2    16    24   14    20

# %%
a.describe()
# Out:
#             col1      col2       col3        cl4       col5
# count   5.000000   5.00000   5.000000   5.000000   5.000000
# mean   10.400000  13.60000   9.800000  17.000000  10.800000
# std     9.181503   6.94982   9.038805   3.872983   5.761944
# min     2.000000   4.00000   1.000000  12.000000   7.000000
# 25%     3.000000  11.00000   3.000000  14.000000   7.000000
# 50%     8.000000  14.00000  10.000000  18.000000   7.000000
# 75%    15.000000  16.00000  11.000000  20.000000  13.000000
# max    24.000000  23.00000  24.000000  21.000000  20.000000

# %%
a.sum(axis=0)#calculate the row sum
# Out:
# col1    52
# col2    68
# col3    49
# cl4     85
# col5    54
# dtype: int64

# %%
a.sum(axis=1) #calculate the column
# Out:
# a    74
# b    63
# c    56
# d    39
# e    76
# dtype: int64

# %%
#to find the correaltion between the values
corr=a.corr()
corr
# Out:
#           col1      col2      col3       cl4      col5
# col1  1.000000 -0.478767 -0.387397 -0.112487 -0.584084
# col2 -0.478767  1.000000  0.551593  0.547990  0.097392
# col3 -0.387397  0.551593  1.000000 -0.171394  0.690270
# cl4  -0.112487  0.547990 -0.171394  1.000000 -0.168042
# col5 -0.584084  0.097392  0.690270 -0.168042  1.000000

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(corr)

# %%
a=DataFrame([[5,6,7,8],[6,np.NaN,4,np.NaN],[np.NaN,3,np.NaN,8]])

a
# Out:
#      0    1    2    3
# 0  5.0  6.0  7.0  8.0
# 1  6.0  NaN  4.0  NaN
# 2  NaN  3.0  NaN  8.0

# %%
a1=a.dropna(axis=0)#row
a1
# Out:
#      0    1    2    3
# 0  5.0  6.0  7.0  8.0

# %%
a1=a.dropna(axis=1)#prints only column
a1
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
a=a.dropna(thresh=3)
a
# Out:
#      0    1    2    3
# 0  5.0  6.0  7.0  8.0

# %%
df=DataFrame([[5,4,3,2,7],[6,2,np.NaN,4,5],[np.NaN,8,9,np.NaN],[np.NaN]])
df
# Out:
#      0    1    2    3    4
# 0  5.0  4.0  3.0  2.0  7.0
# 1  6.0  2.0  NaN  4.0  5.0
# 2  NaN  8.0  9.0  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN

# %%
import numpy as np
import matplotlib.pyplot as plt

# example data
x = np.arange(0.1, 4, 0.1)
y = np.exp(-x)

# example variable error bar values
yerr = 0.1 + 0.1 * np.sqrt(x)


# Now switch to a more OO interface to exercise more features.
fig, axs = plt.subplots(nrows=1, ncols=2, sharex=True)
ax = axs[0]
ax.errorbar(x, y, yerr=yerr)
ax.set_title('all errorbars')

ax = axs[1]
ax.errorbar(x, y, yerr=yerr, errorevery=5)
ax.set_title('only every 5th errorbar')


fig.suptitle('Errorbar subsampling for better appearance')

plt.show()

# %%
#Missing Values
import numpy as np
import pandas as pd
df=pd.DataFrame([[5,4,3,2,7],[6,3,np.NaN,np.NaN,9],[np.NaN,3,4,2,np.NaN]])
df
# Out:
#      0  1    2    3    4
# 0  5.0  4  3.0  2.0  7.0
# 1  6.0  3  NaN  NaN  9.0
# 2  NaN  3  4.0  2.0  NaN

# %%
df1=df.dropna(axis=1)#drop all the columns where null values is available
df1
# Out:
#    1
# 0  4
# 1  3
# 2  3

# %%
df1=df.dropna(axis=0)
df1
# Out:
#      0  1    2    3    4
# 0  5.0  4  3.0  2.0  7.0

# %%
df2=df.dropna(thresh=3)
df2
# Out:
#      0  1    2    3    4
# 0  5.0  4  3.0  2.0  7.0
# 1  6.0  3  NaN  NaN  9.0
# 2  NaN  3  4.0  2.0  NaN

# %%
#fillna
# fill nulls values with 5
df.fillna("5")
# Out:
#    0  1  2  3  4
# 0  5  4  3  2  7
# 1  6  3  5  5  9
# 2  5  3  4  2  5

# %%
#Drop rows
df.drop(0)
# Out:
#      0  1    2    3    4
# 1  6.0  3  NaN  NaN  9.0
# 2  NaN  3  4.0  2.0  NaN

# %%
import pandas as pd
df=pd.read_csv("sales-of-shampoo.csv")
df
# Out:
#     1-01  266.0
# 0   1-02  145.9
# 1   1-03  183.1
# 2   1-04  119.3
# 3   1-05  180.3
# 4   1-06  168.5
# 5   1-07  231.8
# 6   1-08  224.5
# 7   1-09  192.8
# 8   1-10  122.9
# 9   1-11  336.5
# 10  1-12  185.9
# 11  2-01  194.3
# 12  2-02  149.5
# 13  2-03  210.1
# 14  2-04  273.3
# 15  2-05  191.4
# 16  2-06  287.0
# 17  2-07  226.0
# 18  2-08  303.6
# 19  2-09  289.9
# 20  2-10  421.6
# 21  2-11  264.5
# 22  2-12  342.3
# 23  3-01  339.7
# 24  3-02  440.4
# 25  3-03  315.9
# 26  3-04  439.3
# 27  3-05  401.3
# 28  3-06  437.4
# 29  3-07  575.5
# 30  3-08  407.6
# 31  3-09  682.0
# 32  3-10  475.3
# 33  3-11  581.3
# 34  3-12  646.9

# %%
df.head()
# Out:
#    1-01  266.0
# 0  1-02  145.9
# 1  1-03  183.1
# 2  1-04  119.3
# 3  1-05  180.3
# 4  1-06  168.5

# %%
df.shape
# Out:
# (35, 2)

# %%
#sorting the data
df=Series([6,2,7,4],index=["a","b","d","c"])
df
# Out:
# a    6
# b    2
# d    7
# c    4
# dtype: int64

# %%
df.sort_index()
# Out:
# a    6
# b    2
# c    4
# d    7
# dtype: int64

# %%
import matplotlib.pyplot as plot
import numpy as np
x = np.arange(0, 10, 0.2)
y = np.cos(x)#we are using the cos
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
